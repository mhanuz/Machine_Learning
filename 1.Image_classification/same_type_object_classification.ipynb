# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# bash: line 1: syntax error near unexpected token `newline'
# bash: line 1: `<!DOCTYPE html>'

# %%
#read in standard data science libs
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
from  google.colab import drive

# %%
from fastai.vision import *

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_path = 'gdrive/My Drive/Colab Notebooks/beans/'

# %%
proj_path = 'gdrive/My Drive/Colab Notebooks/beans/train/'

# %%
folder=['angular_leaf_spot','bean_rust','healthy']

# %%
p_path = Path(proj_path)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(p_path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes
# Out:
# ['angular_leaf_spot', 'bean_rust', 'healthy']

# %%
data.show_batch(rows=3,figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['angular_leaf_spot', 'bean_rust', 'healthy'], 3, 828, 206)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.505471</td>
#       <td>0.495689</td>
#       <td>0.203883</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.967575</td>
#       <td>0.439679</td>
#       <td>0.140777</td>
#       <td>04:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.745581</td>
#       <td>0.338347</td>
#       <td>0.106796</td>
#       <td>04:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.581428</td>
#       <td>0.282143</td>
#       <td>0.082524</td>
#       <td>04:48</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.492606</td>
#       <td>0.275735</td>
#       <td>0.082524</td>
#       <td>04:53</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('model1_34', return_path=True)
# Out:
# PosixPath('gdrive/My Drive/Colab Notebooks/beans/train/models/model1_34.pth')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [3/9 18:54<37:48]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4), wd=.001)

# %%
learn.freeze()
learn.lr_find()
learn.recorder.plot(

# %%
learn.save('model2_34')

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(10,10))

# %%
img_dragon= open_image(Path(root_path)/'Balls_valid'/'dragonball.png')
img_dragon

# %%
pred_class,pred_idx,outputs = learn.predict(img_dragon)
pred_class
